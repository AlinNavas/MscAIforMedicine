# %%
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from sklearn.metrics import f1_score
# Out:
# WARNING:tensorflow:From c:\Users\alin2\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data_f1 = pd.DataFrame(columns=["pre_type", "f1 score"])

# %%
for pre_type in ["chroma_imgs", "mfcc_imgs", "mel_spectrogram_imgs","spec_imgs","stft_imgs"]:

    train_set= ('./data_pre/{}/train'.format(pre_type))
    test_set=('./data_pre/{}/test'.format(pre_type))
    val_set=('./data_pre/{}/val'.format(pre_type))


    train_datagen = image.ImageDataGenerator(rescale= 1./255)
    val_datagen= image.ImageDataGenerator(rescale= 1./255)
    test_datagen= image.ImageDataGenerator(rescale= 1./255)


    train_generator = train_datagen.flow_from_directory(train_set,batch_size =128 ,class_mode = 'categorical')
    test_generator = test_datagen.flow_from_directory(test_set,shuffle=True,batch_size =128 ,class_mode = 'categorical')
    validation_generator = test_datagen.flow_from_directory(val_set,shuffle=True,batch_size =128 ,class_mode = 'categorical')

    x_train, y_train = next(train_generator)
    x_val,y_val= next(validation_generator)
    x_test, y_test = next(test_generator)

    from keras.applications import ResNet50
    from keras.models import Sequential
    from keras.layers import Dense, Flatten

    # Load the pre-trained ResNet50 model
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

    # Freeze the layers in the base model
    for layer in base_model.layers:
        layer.trainable = False

    # Create a new model
    model = Sequential()

    # Add the ResNet50 base model to the new model
    model.add(base_model)

    # Add custom layers on top of the base model
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(10, activation='softmax'))

    tf.keras.backend.clear_session()

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, mode='min',min_delta=0.001, restore_best_weights=True)
    history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=150,callbacks=[early_stopping], verbose=1)

    predict_y=model.predict(x_test)


    classes_y=np.argmax(predict_y,axis=1)
    y_true= np.argmax(y_test,axis=1)




    epochs = [i for i in range(len(history.epoch))]
    fig , ax = plt.subplots(1,2)
    train_acc = history.history['accuracy']
    train_loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    fig.set_size_inches(20,10)

    ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
    ax[0].plot(epochs , val_acc , 'ro-' , label = 'Val Accuracy')
    ax[0].set_title('Training & Val Accuracy')
    ax[0].legend()
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Accuracy")

    ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
    ax[1].plot(epochs ,  val_loss , 'r-o' , label = 'Val Loss')
    ax[1].set_title('Trainmg and Val Loss')
    ax[1].legend()
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("Loss")
    plt.show()
    f1 = pd.DataFrame({"pre_type": pre_type, "f1 score": f1_score(y_true, classes_y, average='weighted')}, index=[0]) # Changed average to 'macro'
    data_f1 = pd.concat([data_f1,f1], ignore_index=True)
data_f1.to_csv('./perform_csv/ResNet50_f1.csv', index=False)
# Out:
# Found 699 images belonging to 10 classes.
# Found 151 images belonging to 10 classes.
# Found 149 images belonging to 10 classes.
# WARNING:tensorflow:From c:\Users\alin2\anaconda3\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\alin2\anaconda3\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Epoch 1/150
# WARNING:tensorflow:From c:\Users\alin2\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\alin2\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - 7s 2s/step - loss: 32.6418 - accuracy: 0.0938 - val_loss: 39.4996 - val_accuracy: 0.1016
# Epoch 2/150
# 4/4 [==============================] - 5s 1s/step - loss: 24.5671 - accuracy: 0.0781 - val_loss: 11.6312 - val_accuracy: 0.2031
# Epoch 3/150
# 4/4 [==============================] - 5s 1s/step - loss: 8.7358 - accuracy: 0.1406 - val_loss: 6.3571 - val_accuracy: 0.1094
# Epoch 4/150
# 4/4 [==============================] - 5s 1s/step - loss: 5.4885 - accuracy: 0.1641 - val_loss: 4.8080 - val_accuracy: 0.1016
# Epoch 5/150
# 4/4 [==============================] - 5s 1s/step - loss: 4.1034 - accuracy: 0.1172 - val_loss: 3.6023 - val_accuracy: 0.1094
# Epoch 6/150
# 4/4 [==============================] - 5s 1s/step - loss: 3.1273 - accuracy: 0.0547 - val_loss: 2.4445 - val_accuracy: 0.1250
# Epoch 7/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3899 - accuracy: 0.0938 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 8/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3031 - accuracy: 0.0781 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 9/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.3030 - accuracy: 0.0781 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 10/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.3030 - accuracy: 0.0781 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 11/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.3029 - accuracy: 0.0781 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 12/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3028 - accuracy: 0.0781 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 13/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.3027 - accuracy: 0.0781 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 14/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.3026 - accuracy: 0.0781 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 15/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3025 - accuracy: 0.0781 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 16/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.3024 - accuracy: 0.1172 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 17/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3023 - accuracy: 0.1328 - val_loss: 2.3027 - val_accuracy: 0.1016
# 4/4 [==============================] - 3s 520ms/step
# Found 699 images belonging to 10 classes.
# Found 151 images belonging to 10 classes.
# Found 149 images belonging to 10 classes.
# Epoch 1/150
# 4/4 [==============================] - 7s 2s/step - loss: 25.5553 - accuracy: 0.1328 - val_loss: 48.2689 - val_accuracy: 0.1016
# Epoch 2/150
# 4/4 [==============================] - 5s 1s/step - loss: 49.4957 - accuracy: 0.1094 - val_loss: 36.3240 - val_accuracy: 0.0781
# Epoch 3/150
# 4/4 [==============================] - 5s 1s/step - loss: 29.1456 - accuracy: 0.1406 - val_loss: 21.2220 - val_accuracy: 0.1172
# Epoch 4/150
# 4/4 [==============================] - 5s 1s/step - loss: 19.3940 - accuracy: 0.0625 - val_loss: 11.2622 - val_accuracy: 0.0938
# Epoch 5/150
# 4/4 [==============================] - 5s 1s/step - loss: 9.3188 - accuracy: 0.0781 - val_loss: 7.5077 - val_accuracy: 0.0781
# Epoch 6/150
# 4/4 [==============================] - 5s 1s/step - loss: 7.1382 - accuracy: 0.0938 - val_loss: 5.5273 - val_accuracy: 0.1484
# Epoch 7/150
# 4/4 [==============================] - 5s 1s/step - loss: 5.4276 - accuracy: 0.0859 - val_loss: 4.5556 - val_accuracy: 0.1172
# Epoch 8/150
# 4/4 [==============================] - 5s 1s/step - loss: 4.6245 - accuracy: 0.1719 - val_loss: 3.9045 - val_accuracy: 0.1641
# Epoch 9/150
# 4/4 [==============================] - 5s 1s/step - loss: 3.6951 - accuracy: 0.1250 - val_loss: 3.2438 - val_accuracy: 0.0781
# Epoch 10/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.8315 - accuracy: 0.0859 - val_loss: 2.7189 - val_accuracy: 0.1172
# Epoch 11/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.6119 - accuracy: 0.1797 - val_loss: 2.2801 - val_accuracy: 0.1172
# Epoch 12/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2898 - accuracy: 0.1094 - val_loss: 2.3615 - val_accuracy: 0.0859
# Epoch 13/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2858 - accuracy: 0.0859 - val_loss: 2.2741 - val_accuracy: 0.1484
# Epoch 14/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2905 - accuracy: 0.1172 - val_loss: 2.3002 - val_accuracy: 0.1094
# Epoch 15/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2983 - accuracy: 0.1094 - val_loss: 2.2991 - val_accuracy: 0.1094
# Epoch 16/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2950 - accuracy: 0.1094 - val_loss: 2.2800 - val_accuracy: 0.1484
# Epoch 17/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2605 - accuracy: 0.1172 - val_loss: 2.3065 - val_accuracy: 0.0781
# Epoch 18/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2613 - accuracy: 0.0859 - val_loss: 2.2648 - val_accuracy: 0.1328
# Epoch 19/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2879 - accuracy: 0.1172 - val_loss: 2.2932 - val_accuracy: 0.1250
# Epoch 20/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2875 - accuracy: 0.1094 - val_loss: 2.2614 - val_accuracy: 0.1328
# Epoch 21/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2509 - accuracy: 0.1250 - val_loss: 2.3035 - val_accuracy: 0.0781
# Epoch 22/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2686 - accuracy: 0.1250 - val_loss: 2.2625 - val_accuracy: 0.1562
# Epoch 23/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2687 - accuracy: 0.1406 - val_loss: 2.2675 - val_accuracy: 0.0938
# Epoch 24/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2702 - accuracy: 0.1250 - val_loss: 2.2612 - val_accuracy: 0.1484
# Epoch 25/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2506 - accuracy: 0.1484 - val_loss: 2.2792 - val_accuracy: 0.0781
# Epoch 26/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2540 - accuracy: 0.1172 - val_loss: 2.2583 - val_accuracy: 0.1406
# Epoch 27/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.2720 - accuracy: 0.1406 - val_loss: 2.2653 - val_accuracy: 0.1641
# Epoch 28/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.2595 - accuracy: 0.1875 - val_loss: 2.2686 - val_accuracy: 0.0781
# Epoch 29/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2387 - accuracy: 0.1016 - val_loss: 2.2485 - val_accuracy: 0.1562
# Epoch 30/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2421 - accuracy: 0.1875 - val_loss: 2.2540 - val_accuracy: 0.1172
# Epoch 31/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2358 - accuracy: 0.1406 - val_loss: 2.2466 - val_accuracy: 0.1406
# Epoch 32/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.2521 - accuracy: 0.1484 - val_loss: 2.2473 - val_accuracy: 0.1406
# Epoch 33/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2383 - accuracy: 0.1562 - val_loss: 2.3399 - val_accuracy: 0.0781
# Epoch 34/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2627 - accuracy: 0.1406 - val_loss: 2.2646 - val_accuracy: 0.1562
# Epoch 35/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2776 - accuracy: 0.1250 - val_loss: 2.2868 - val_accuracy: 0.1172
# Epoch 36/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2819 - accuracy: 0.1172 - val_loss: 2.2775 - val_accuracy: 0.1094
# Epoch 37/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2578 - accuracy: 0.1172 - val_loss: 2.3412 - val_accuracy: 0.0781
# Epoch 38/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2659 - accuracy: 0.0938 - val_loss: 2.2517 - val_accuracy: 0.1328
# Epoch 39/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2578 - accuracy: 0.1406 - val_loss: 2.2527 - val_accuracy: 0.1250
# Epoch 40/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2400 - accuracy: 0.1562 - val_loss: 2.2696 - val_accuracy: 0.0859
# Epoch 41/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2251 - accuracy: 0.1250 - val_loss: 2.2373 - val_accuracy: 0.1172
# Epoch 42/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2324 - accuracy: 0.1406 - val_loss: 2.2473 - val_accuracy: 0.1172
# Epoch 43/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2241 - accuracy: 0.1406 - val_loss: 2.2427 - val_accuracy: 0.1172
# Epoch 44/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2299 - accuracy: 0.1484 - val_loss: 2.2384 - val_accuracy: 0.1172
# Epoch 45/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2271 - accuracy: 0.1406 - val_loss: 2.2363 - val_accuracy: 0.1094
# Epoch 46/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2216 - accuracy: 0.1406 - val_loss: 2.2539 - val_accuracy: 0.1172
# Epoch 47/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2244 - accuracy: 0.1484 - val_loss: 2.2396 - val_accuracy: 0.1094
# Epoch 48/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2243 - accuracy: 0.1406 - val_loss: 2.2575 - val_accuracy: 0.1172
# Epoch 49/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2298 - accuracy: 0.1484 - val_loss: 2.2316 - val_accuracy: 0.1250
# Epoch 50/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2162 - accuracy: 0.1484 - val_loss: 2.2601 - val_accuracy: 0.1172
# Epoch 51/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2264 - accuracy: 0.1797 - val_loss: 2.2307 - val_accuracy: 0.1250
# Epoch 52/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2249 - accuracy: 0.1484 - val_loss: 2.2717 - val_accuracy: 0.1172
# Epoch 53/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2164 - accuracy: 0.1719 - val_loss: 2.2292 - val_accuracy: 0.1250
# Epoch 54/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2341 - accuracy: 0.1406 - val_loss: 2.2644 - val_accuracy: 0.1094
# Epoch 55/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2393 - accuracy: 0.1562 - val_loss: 2.2353 - val_accuracy: 0.1094
# Epoch 56/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2209 - accuracy: 0.1641 - val_loss: 2.2831 - val_accuracy: 0.1172
# Epoch 57/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2342 - accuracy: 0.1562 - val_loss: 2.2377 - val_accuracy: 0.1094
# Epoch 58/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2600 - accuracy: 0.1719 - val_loss: 2.2826 - val_accuracy: 0.1172
# Epoch 59/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2727 - accuracy: 0.1719 - val_loss: 2.2711 - val_accuracy: 0.1172
# Epoch 60/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2544 - accuracy: 0.1719 - val_loss: 2.2243 - val_accuracy: 0.1250
# Epoch 61/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2167 - accuracy: 0.1406 - val_loss: 2.2635 - val_accuracy: 0.1250
# Epoch 62/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2392 - accuracy: 0.1484 - val_loss: 2.2294 - val_accuracy: 0.1016
# Epoch 63/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2191 - accuracy: 0.1562 - val_loss: 2.2554 - val_accuracy: 0.1328
# Epoch 64/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2141 - accuracy: 0.1562 - val_loss: 2.2283 - val_accuracy: 0.1250
# Epoch 65/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2145 - accuracy: 0.1484 - val_loss: 2.2261 - val_accuracy: 0.1250
# Epoch 66/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2201 - accuracy: 0.1641 - val_loss: 2.2207 - val_accuracy: 0.1250
# Epoch 67/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2109 - accuracy: 0.1797 - val_loss: 2.2436 - val_accuracy: 0.1484
# Epoch 68/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2076 - accuracy: 0.2109 - val_loss: 2.2204 - val_accuracy: 0.1328
# Epoch 69/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2113 - accuracy: 0.1875 - val_loss: 2.2370 - val_accuracy: 0.1562
# Epoch 70/150
# 4/4 [==============================] - 5s 2s/step - loss: 2.2148 - accuracy: 0.2031 - val_loss: 2.2183 - val_accuracy: 0.1406
# Epoch 71/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.1979 - accuracy: 0.2031 - val_loss: 2.2889 - val_accuracy: 0.1406
# Epoch 72/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2374 - accuracy: 0.2031 - val_loss: 2.2195 - val_accuracy: 0.1406
# Epoch 73/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2114 - accuracy: 0.2031 - val_loss: 2.2331 - val_accuracy: 0.1562
# Epoch 74/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.1955 - accuracy: 0.1953 - val_loss: 2.2201 - val_accuracy: 0.1484
# Epoch 75/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.1982 - accuracy: 0.2031 - val_loss: 2.2488 - val_accuracy: 0.1484
# Epoch 76/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2019 - accuracy: 0.2031 - val_loss: 2.2158 - val_accuracy: 0.1484
# Epoch 77/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.1955 - accuracy: 0.1953 - val_loss: 2.2806 - val_accuracy: 0.1328
# Epoch 78/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2046 - accuracy: 0.2031 - val_loss: 2.2146 - val_accuracy: 0.1406
# Epoch 79/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2140 - accuracy: 0.2109 - val_loss: 2.2159 - val_accuracy: 0.1484
# Epoch 80/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2466 - accuracy: 0.1875 - val_loss: 2.2130 - val_accuracy: 0.1484
# Epoch 81/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2470 - accuracy: 0.1875 - val_loss: 2.2967 - val_accuracy: 0.1172
# Epoch 82/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2870 - accuracy: 0.1719 - val_loss: 2.3033 - val_accuracy: 0.1172
# Epoch 83/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2906 - accuracy: 0.1719 - val_loss: 2.3034 - val_accuracy: 0.1172
# Epoch 84/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2904 - accuracy: 0.1719 - val_loss: 2.3034 - val_accuracy: 0.1172
# Epoch 85/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2902 - accuracy: 0.1719 - val_loss: 2.3035 - val_accuracy: 0.1172
# Epoch 86/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2899 - accuracy: 0.1719 - val_loss: 2.3035 - val_accuracy: 0.1172
# Epoch 87/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2897 - accuracy: 0.1719 - val_loss: 2.3036 - val_accuracy: 0.1172
# Epoch 88/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2895 - accuracy: 0.1719 - val_loss: 2.3036 - val_accuracy: 0.1172
# Epoch 89/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2892 - accuracy: 0.1719 - val_loss: 2.3037 - val_accuracy: 0.1172
# Epoch 90/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2890 - accuracy: 0.1719 - val_loss: 2.3037 - val_accuracy: 0.1172
# 4/4 [==============================] - 3s 524ms/step
# Found 699 images belonging to 10 classes.
# Found 151 images belonging to 10 classes.
# Found 149 images belonging to 10 classes.
# Epoch 1/150
# 4/4 [==============================] - 6s 2s/step - loss: 33.3378 - accuracy: 0.1562 - val_loss: 42.2905 - val_accuracy: 0.1094
# Epoch 2/150
# 4/4 [==============================] - 5s 1s/step - loss: 42.2255 - accuracy: 0.0938 - val_loss: 38.9680 - val_accuracy: 0.0938
# Epoch 3/150
# 4/4 [==============================] - 5s 1s/step - loss: 29.5373 - accuracy: 0.0859 - val_loss: 18.1742 - val_accuracy: 0.0859
# Epoch 4/150
# 4/4 [==============================] - 5s 1s/step - loss: 17.6210 - accuracy: 0.0938 - val_loss: 10.6001 - val_accuracy: 0.1562
# Epoch 5/150
# 4/4 [==============================] - 5s 1s/step - loss: 9.7043 - accuracy: 0.1719 - val_loss: 8.8963 - val_accuracy: 0.0859
# Epoch 6/150
# 4/4 [==============================] - 5s 1s/step - loss: 6.7377 - accuracy: 0.1484 - val_loss: 4.9425 - val_accuracy: 0.1016
# Epoch 7/150
# 4/4 [==============================] - 5s 1s/step - loss: 4.3363 - accuracy: 0.1016 - val_loss: 3.7584 - val_accuracy: 0.1094
# Epoch 8/150
# 4/4 [==============================] - 5s 1s/step - loss: 3.6997 - accuracy: 0.1562 - val_loss: 3.4148 - val_accuracy: 0.1016
# Epoch 9/150
# 4/4 [==============================] - 5s 1s/step - loss: 3.0479 - accuracy: 0.1328 - val_loss: 2.7867 - val_accuracy: 0.1094
# Epoch 10/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.6390 - accuracy: 0.1172 - val_loss: 2.4478 - val_accuracy: 0.1016
# Epoch 11/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.4326 - accuracy: 0.0938 - val_loss: 2.3239 - val_accuracy: 0.1094
# Epoch 12/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3045 - accuracy: 0.0703 - val_loss: 2.3026 - val_accuracy: 0.0938
# Epoch 13/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3027 - accuracy: 0.0859 - val_loss: 2.3026 - val_accuracy: 0.0938
# Epoch 14/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3026 - accuracy: 0.0859 - val_loss: 2.3026 - val_accuracy: 0.0938
# Epoch 15/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3025 - accuracy: 0.0859 - val_loss: 2.3027 - val_accuracy: 0.0938
# Epoch 16/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3024 - accuracy: 0.0859 - val_loss: 2.3027 - val_accuracy: 0.0938
# Epoch 17/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3023 - accuracy: 0.0859 - val_loss: 2.3027 - val_accuracy: 0.0938
# Epoch 18/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3022 - accuracy: 0.0859 - val_loss: 2.3027 - val_accuracy: 0.0938
# Epoch 19/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3020 - accuracy: 0.0859 - val_loss: 2.3027 - val_accuracy: 0.0938
# Epoch 20/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3019 - accuracy: 0.1172 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 21/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3018 - accuracy: 0.1406 - val_loss: 2.3027 - val_accuracy: 0.1016
# Epoch 22/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3016 - accuracy: 0.1406 - val_loss: 2.3027 - val_accuracy: 0.1016
# 4/4 [==============================] - 2s 521ms/step
# Found 699 images belonging to 10 classes.
# Found 151 images belonging to 10 classes.
# Found 149 images belonging to 10 classes.
# Epoch 1/150
# 4/4 [==============================] - 7s 2s/step - loss: 30.9253 - accuracy: 0.0938 - val_loss: 48.7305 - val_accuracy: 0.0859
# Epoch 2/150
# 4/4 [==============================] - 5s 1s/step - loss: 36.2463 - accuracy: 0.0859 - val_loss: 27.6986 - val_accuracy: 0.1016
# Epoch 3/150
# 4/4 [==============================] - 5s 1s/step - loss: 26.5855 - accuracy: 0.0703 - val_loss: 24.5259 - val_accuracy: 0.1094
# Epoch 4/150
# 4/4 [==============================] - 5s 1s/step - loss: 19.7435 - accuracy: 0.1406 - val_loss: 13.4975 - val_accuracy: 0.1094
# Epoch 5/150
# 4/4 [==============================] - 5s 1s/step - loss: 9.3554 - accuracy: 0.1250 - val_loss: 5.8721 - val_accuracy: 0.1094
# Epoch 6/150
# 4/4 [==============================] - 5s 1s/step - loss: 5.3170 - accuracy: 0.1094 - val_loss: 6.6707 - val_accuracy: 0.1094
# Epoch 7/150
# 4/4 [==============================] - 5s 1s/step - loss: 4.5208 - accuracy: 0.1484 - val_loss: 3.9643 - val_accuracy: 0.1016
# Epoch 8/150
# 4/4 [==============================] - 5s 1s/step - loss: 3.0686 - accuracy: 0.1406 - val_loss: 2.8556 - val_accuracy: 0.1797
# Epoch 9/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.5393 - accuracy: 0.1719 - val_loss: 2.5646 - val_accuracy: 0.1094
# Epoch 10/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.4646 - accuracy: 0.1172 - val_loss: 2.3764 - val_accuracy: 0.1016
# Epoch 11/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2657 - accuracy: 0.1172 - val_loss: 2.4336 - val_accuracy: 0.1016
# Epoch 12/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2597 - accuracy: 0.1562 - val_loss: 2.4002 - val_accuracy: 0.1094
# Epoch 13/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3017 - accuracy: 0.1094 - val_loss: 2.3878 - val_accuracy: 0.1641
# Epoch 14/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3196 - accuracy: 0.1797 - val_loss: 2.2790 - val_accuracy: 0.1328
# Epoch 15/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2846 - accuracy: 0.1562 - val_loss: 2.3057 - val_accuracy: 0.1250
# Epoch 16/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2787 - accuracy: 0.1797 - val_loss: 2.2665 - val_accuracy: 0.1328
# Epoch 17/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2014 - accuracy: 0.1562 - val_loss: 2.2836 - val_accuracy: 0.1094
# Epoch 18/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2221 - accuracy: 0.2344 - val_loss: 2.2455 - val_accuracy: 0.1406
# Epoch 19/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.1423 - accuracy: 0.2344 - val_loss: 2.2497 - val_accuracy: 0.1250
# Epoch 20/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.2158 - accuracy: 0.1641 - val_loss: 2.3113 - val_accuracy: 0.1172
# Epoch 21/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2459 - accuracy: 0.1797 - val_loss: 2.2279 - val_accuracy: 0.2344
# Epoch 22/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.2189 - accuracy: 0.2422 - val_loss: 2.3957 - val_accuracy: 0.1094
# Epoch 23/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3125 - accuracy: 0.1250 - val_loss: 2.3692 - val_accuracy: 0.1484
# Epoch 24/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.1424 - accuracy: 0.2500 - val_loss: 2.2356 - val_accuracy: 0.2109
# Epoch 25/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.1111 - accuracy: 0.2656 - val_loss: 2.2546 - val_accuracy: 0.0859
# Epoch 26/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.1818 - accuracy: 0.1562 - val_loss: 2.3313 - val_accuracy: 0.1406
# Epoch 27/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.1686 - accuracy: 0.1719 - val_loss: 2.3292 - val_accuracy: 0.1406
# Epoch 28/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.1704 - accuracy: 0.1562 - val_loss: 2.2675 - val_accuracy: 0.1172
# Epoch 29/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.1326 - accuracy: 0.2266 - val_loss: 2.2758 - val_accuracy: 0.1875
# Epoch 30/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.1392 - accuracy: 0.2188 - val_loss: 2.2339 - val_accuracy: 0.0859
# Epoch 31/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.1537 - accuracy: 0.1797 - val_loss: 2.3000 - val_accuracy: 0.1641
# 4/4 [==============================] - 3s 521ms/step
# Found 699 images belonging to 10 classes.
# Found 151 images belonging to 10 classes.
# Found 149 images belonging to 10 classes.
# Epoch 1/150
# 4/4 [==============================] - 6s 2s/step - loss: 37.9391 - accuracy: 0.1016 - val_loss: 46.0963 - val_accuracy: 0.1016
# Epoch 2/150
# 4/4 [==============================] - 5s 1s/step - loss: 34.1559 - accuracy: 0.0938 - val_loss: 20.4270 - val_accuracy: 0.0938
# Epoch 3/150
# 4/4 [==============================] - 5s 1s/step - loss: 17.1390 - accuracy: 0.0938 - val_loss: 8.2595 - val_accuracy: 0.1094
# Epoch 4/150
# 4/4 [==============================] - 5s 1s/step - loss: 9.0395 - accuracy: 0.1250 - val_loss: 5.8618 - val_accuracy: 0.0859
# Epoch 5/150
# 4/4 [==============================] - 5s 1s/step - loss: 4.8731 - accuracy: 0.0781 - val_loss: 5.1949 - val_accuracy: 0.0938
# Epoch 6/150
# 4/4 [==============================] - 5s 1s/step - loss: 4.5706 - accuracy: 0.1094 - val_loss: 3.7946 - val_accuracy: 0.1094
# Epoch 7/150
# 4/4 [==============================] - 5s 1s/step - loss: 3.3163 - accuracy: 0.0859 - val_loss: 2.6286 - val_accuracy: 0.0938
# Epoch 8/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.4418 - accuracy: 0.0703 - val_loss: 2.3028 - val_accuracy: 0.0859
# Epoch 9/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3029 - accuracy: 0.0703 - val_loss: 2.3028 - val_accuracy: 0.0859
# Epoch 10/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.3028 - accuracy: 0.0703 - val_loss: 2.3027 - val_accuracy: 0.0859
# Epoch 11/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3027 - accuracy: 0.0703 - val_loss: 2.3027 - val_accuracy: 0.0859
# Epoch 12/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3025 - accuracy: 0.0703 - val_loss: 2.3027 - val_accuracy: 0.0859
# Epoch 13/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3024 - accuracy: 0.0703 - val_loss: 2.3026 - val_accuracy: 0.0859
# Epoch 14/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.3023 - accuracy: 0.0703 - val_loss: 2.3026 - val_accuracy: 0.0859
# Epoch 15/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.3021 - accuracy: 0.0859 - val_loss: 2.3025 - val_accuracy: 0.1094
# Epoch 16/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3019 - accuracy: 0.1328 - val_loss: 2.3025 - val_accuracy: 0.1094
# Epoch 17/150
# 4/4 [==============================] - 4s 1s/step - loss: 2.3017 - accuracy: 0.1328 - val_loss: 2.3025 - val_accuracy: 0.1094
# Epoch 18/150
# 4/4 [==============================] - 5s 1s/step - loss: 2.3016 - accuracy: 0.1328 - val_loss: 2.3024 - val_accuracy: 0.1094
# 4/4 [==============================] - 3s 526ms/step
