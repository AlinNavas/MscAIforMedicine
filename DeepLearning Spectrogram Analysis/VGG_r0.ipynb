# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D

from keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.activations import swish, relu,selu

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'

train_set= ('./Experiments/data_pre/mel_spectrogram_imgs/train')
test_set=('./Experiments/data_pre/mel_spectrogram_imgs/test')
val_set= ('./Experiments/data_pre/mel_spectrogram_imgs/val')

train_datagen = image.ImageDataGenerator(rescale= 1./255)
val_datagen= image.ImageDataGenerator(rescale= 1./255)
test_datagen= image.ImageDataGenerator(rescale= 1./255)


train_generator = train_datagen.flow_from_directory(train_set,batch_size =512 ,class_mode = 'categorical')
test_generator = test_datagen.flow_from_directory(test_set,shuffle=True,batch_size =128 ,class_mode = 'categorical')
validation_generator = test_datagen.flow_from_directory(val_set,shuffle=True,batch_size =128 ,class_mode = 'categorical')
x_train, y_train = next(train_generator)
x_val,y_val= next(validation_generator)
x_test, y_test = next(test_generator)
# Out:
# 2024-05-03 17:16:46.150197: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-03 17:16:46.427369: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-03 17:16:46.427407: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-03 17:16:46.480767: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 17:16:46.579331: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 17:16:47.334914: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found 699 images belonging to 10 classes.
# Found 151 images belonging to 10 classes.
# Found 149 images belonging to 10 classes.

# %%
best_params = {'num_layers': 1, 'num_neurons': 1765, 'learning_rate': 0.00129210005319751};

# %%
from keras.callbacks import CSVLogger
from keras.callbacks import ModelCheckpoint


# Access the individual hyperparameters
learning_rate = best_params['learning_rate']
num_layers = best_params['num_layers']
num_neurons = best_params['num_neurons']

# Use the best hyperparameters in your code
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# Freeze the layers in the base model
for layer in base_model.layers[:-num_layers]:
    layer.trainable = False

# Create a new model
model = Sequential()

# Add the VGG16 base model to the new model
model.add(base_model)
model.add(Flatten())
model.add(Dense(num_neurons, input_shape=(x_train.shape[1],)))
model.add(Activation(relu))
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))

# Compile the model with hyperparameters
model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with hyperparameters
csv_logger = CSVLogger('./logs/VGG_r0_training.csv')
# Define the checkpoint callback
checkpoint = ModelCheckpoint(filepath='./model_weights/VGG_r0_model_weights.h5', 
                             monitor='val_loss', 
                             save_best_only=True,
                             save_weights_only=True,
                             mode='min',
                             verbose=1)


early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, mode='min', min_delta=0.0001, restore_best_weights=True)
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=150, callbacks=[early_stopping,checkpoint,csv_logger], verbose=1)
# Out:
# 2024-05-03 17:16:56.194571: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:16:56.360091: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:16:56.360119: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:16:56.362955: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:16:56.362982: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:16:56.362996: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:16:56.612695: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:16:56.612731: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:16:56.612735: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-05-03 17:16:56.612752: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:16:56.612764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5535 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/150
# 2024-05-03 17:16:57.705714: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-05-03 17:16:57.895070: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-03 17:17:00.196825: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-03 17:17:00.532257: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f3703f74200 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-03 17:17:00.532277: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# 2024-05-03 17:17:00.543284: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714753020.603935    2101 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 16/16 [==============================] - ETA: 0s - loss: 15.1723 - accuracy: 0.1172
# Epoch 1: val_loss improved from inf to 4.58951, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 6s 184ms/step - loss: 15.1723 - accuracy: 0.1172 - val_loss: 4.5895 - val_accuracy: 0.1094
# Epoch 2/150
# 16/16 [==============================] - ETA: 0s - loss: 3.3519 - accuracy: 0.1992
# Epoch 2: val_loss improved from 4.58951 to 1.90252, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 168ms/step - loss: 3.3519 - accuracy: 0.1992 - val_loss: 1.9025 - val_accuracy: 0.3750
# Epoch 3/150
# 16/16 [==============================] - ETA: 0s - loss: 1.9802 - accuracy: 0.3301
# Epoch 3: val_loss improved from 1.90252 to 1.88864, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 167ms/step - loss: 1.9802 - accuracy: 0.3301 - val_loss: 1.8886 - val_accuracy: 0.3359
# Epoch 4/150
# 16/16 [==============================] - ETA: 0s - loss: 1.7430 - accuracy: 0.3809
# Epoch 4: val_loss improved from 1.88864 to 1.81340, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 167ms/step - loss: 1.7430 - accuracy: 0.3809 - val_loss: 1.8134 - val_accuracy: 0.3828
# Epoch 5/150
# 16/16 [==============================] - ETA: 0s - loss: 1.5923 - accuracy: 0.4355
# Epoch 5: val_loss improved from 1.81340 to 1.74818, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 169ms/step - loss: 1.5923 - accuracy: 0.4355 - val_loss: 1.7482 - val_accuracy: 0.4297
# Epoch 6/150
# 16/16 [==============================] - ETA: 0s - loss: 1.5817 - accuracy: 0.4297
# Epoch 6: val_loss improved from 1.74818 to 1.65103, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 168ms/step - loss: 1.5817 - accuracy: 0.4297 - val_loss: 1.6510 - val_accuracy: 0.4844
# Epoch 7/150
# 16/16 [==============================] - ETA: 0s - loss: 1.4729 - accuracy: 0.4941
# Epoch 7: val_loss did not improve from 1.65103
# 16/16 [==============================] - 2s 151ms/step - loss: 1.4729 - accuracy: 0.4941 - val_loss: 1.6780 - val_accuracy: 0.4375
# Epoch 8/150
# 16/16 [==============================] - ETA: 0s - loss: 1.4365 - accuracy: 0.5156
# Epoch 8: val_loss improved from 1.65103 to 1.56355, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 168ms/step - loss: 1.4365 - accuracy: 0.5156 - val_loss: 1.5636 - val_accuracy: 0.4922
# Epoch 9/150
# 16/16 [==============================] - ETA: 0s - loss: 1.3166 - accuracy: 0.5293
# Epoch 9: val_loss improved from 1.56355 to 1.50714, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 169ms/step - loss: 1.3166 - accuracy: 0.5293 - val_loss: 1.5071 - val_accuracy: 0.5234
# Epoch 10/150
# 16/16 [==============================] - ETA: 0s - loss: 1.2341 - accuracy: 0.5840
# Epoch 10: val_loss improved from 1.50714 to 1.44326, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 168ms/step - loss: 1.2341 - accuracy: 0.5840 - val_loss: 1.4433 - val_accuracy: 0.4844
# Epoch 11/150
# 16/16 [==============================] - ETA: 0s - loss: 1.2824 - accuracy: 0.5605
# Epoch 11: val_loss did not improve from 1.44326
# 16/16 [==============================] - 2s 151ms/step - loss: 1.2824 - accuracy: 0.5605 - val_loss: 1.4693 - val_accuracy: 0.4844
# Epoch 12/150
# 16/16 [==============================] - ETA: 0s - loss: 1.1760 - accuracy: 0.5918
# Epoch 12: val_loss improved from 1.44326 to 1.37842, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 168ms/step - loss: 1.1760 - accuracy: 0.5918 - val_loss: 1.3784 - val_accuracy: 0.5000
# Epoch 13/150
# 16/16 [==============================] - ETA: 0s - loss: 1.0559 - accuracy: 0.6504
# Epoch 13: val_loss did not improve from 1.37842
# 16/16 [==============================] - 2s 151ms/step - loss: 1.0559 - accuracy: 0.6504 - val_loss: 1.3970 - val_accuracy: 0.5078
# Epoch 14/150
# 16/16 [==============================] - ETA: 0s - loss: 1.0492 - accuracy: 0.6426
# Epoch 14: val_loss did not improve from 1.37842
# 16/16 [==============================] - 2s 151ms/step - loss: 1.0492 - accuracy: 0.6426 - val_loss: 1.3825 - val_accuracy: 0.5312
# Epoch 15/150
# 16/16 [==============================] - ETA: 0s - loss: 0.9832 - accuracy: 0.6562
# Epoch 15: val_loss did not improve from 1.37842
# 16/16 [==============================] - 2s 151ms/step - loss: 0.9832 - accuracy: 0.6562 - val_loss: 1.3891 - val_accuracy: 0.5234
# Epoch 16/150
# 16/16 [==============================] - ETA: 0s - loss: 0.9509 - accuracy: 0.6855
# Epoch 16: val_loss improved from 1.37842 to 1.37577, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 168ms/step - loss: 0.9509 - accuracy: 0.6855 - val_loss: 1.3758 - val_accuracy: 0.4922
# Epoch 17/150
# 16/16 [==============================] - ETA: 0s - loss: 0.9196 - accuracy: 0.6816
# Epoch 17: val_loss improved from 1.37577 to 1.32358, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 173ms/step - loss: 0.9196 - accuracy: 0.6816 - val_loss: 1.3236 - val_accuracy: 0.5156
# Epoch 18/150
# 16/16 [==============================] - ETA: 0s - loss: 0.8834 - accuracy: 0.6738
# Epoch 18: val_loss did not improve from 1.32358
# 16/16 [==============================] - 2s 154ms/step - loss: 0.8834 - accuracy: 0.6738 - val_loss: 1.3286 - val_accuracy: 0.5312
# Epoch 19/150
# 16/16 [==============================] - ETA: 0s - loss: 0.8623 - accuracy: 0.7070
# Epoch 19: val_loss improved from 1.32358 to 1.29708, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 171ms/step - loss: 0.8623 - accuracy: 0.7070 - val_loss: 1.2971 - val_accuracy: 0.5547
# Epoch 20/150
# 16/16 [==============================] - ETA: 0s - loss: 0.8193 - accuracy: 0.7422
# Epoch 20: val_loss did not improve from 1.29708
# 16/16 [==============================] - 2s 154ms/step - loss: 0.8193 - accuracy: 0.7422 - val_loss: 1.3791 - val_accuracy: 0.5469
# Epoch 21/150
# 16/16 [==============================] - ETA: 0s - loss: 0.8115 - accuracy: 0.7227
# Epoch 21: val_loss did not improve from 1.29708
# 16/16 [==============================] - 2s 155ms/step - loss: 0.8115 - accuracy: 0.7227 - val_loss: 1.3753 - val_accuracy: 0.5391
# Epoch 22/150
# 16/16 [==============================] - ETA: 0s - loss: 0.8105 - accuracy: 0.7227
# Epoch 22: val_loss did not improve from 1.29708
# 16/16 [==============================] - 2s 150ms/step - loss: 0.8105 - accuracy: 0.7227 - val_loss: 1.3651 - val_accuracy: 0.5078
# Epoch 23/150
# 16/16 [==============================] - ETA: 0s - loss: 0.7137 - accuracy: 0.7422
# Epoch 23: val_loss improved from 1.29708 to 1.29409, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 169ms/step - loss: 0.7137 - accuracy: 0.7422 - val_loss: 1.2941 - val_accuracy: 0.5469
# Epoch 24/150
# 16/16 [==============================] - ETA: 0s - loss: 0.6907 - accuracy: 0.7734
# Epoch 24: val_loss improved from 1.29409 to 1.27647, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 168ms/step - loss: 0.6907 - accuracy: 0.7734 - val_loss: 1.2765 - val_accuracy: 0.5391
# Epoch 25/150
# 16/16 [==============================] - ETA: 0s - loss: 0.6428 - accuracy: 0.7949
# Epoch 25: val_loss improved from 1.27647 to 1.24105, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 168ms/step - loss: 0.6428 - accuracy: 0.7949 - val_loss: 1.2411 - val_accuracy: 0.5703
# Epoch 26/150
# 16/16 [==============================] - ETA: 0s - loss: 0.6214 - accuracy: 0.7910
# Epoch 26: val_loss did not improve from 1.24105
# 16/16 [==============================] - 2s 151ms/step - loss: 0.6214 - accuracy: 0.7910 - val_loss: 1.2703 - val_accuracy: 0.5391
# Epoch 27/150
# 16/16 [==============================] - ETA: 0s - loss: 0.6453 - accuracy: 0.8008
# Epoch 27: val_loss improved from 1.24105 to 1.23457, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 167ms/step - loss: 0.6453 - accuracy: 0.8008 - val_loss: 1.2346 - val_accuracy: 0.5625
# Epoch 28/150
# 16/16 [==============================] - ETA: 0s - loss: 0.5539 - accuracy: 0.8398
# Epoch 28: val_loss did not improve from 1.23457
# 16/16 [==============================] - 2s 151ms/step - loss: 0.5539 - accuracy: 0.8398 - val_loss: 1.3038 - val_accuracy: 0.5469
# Epoch 29/150
# 16/16 [==============================] - ETA: 0s - loss: 0.5770 - accuracy: 0.8203
# Epoch 29: val_loss did not improve from 1.23457
# 16/16 [==============================] - 2s 152ms/step - loss: 0.5770 - accuracy: 0.8203 - val_loss: 1.3425 - val_accuracy: 0.4922
# Epoch 30/150
# 16/16 [==============================] - ETA: 0s - loss: 0.5819 - accuracy: 0.8242
# Epoch 30: val_loss did not improve from 1.23457
# 16/16 [==============================] - 2s 151ms/step - loss: 0.5819 - accuracy: 0.8242 - val_loss: 1.4479 - val_accuracy: 0.5391
# Epoch 31/150
# 16/16 [==============================] - ETA: 0s - loss: 0.5247 - accuracy: 0.8477
# Epoch 31: val_loss did not improve from 1.23457
# 16/16 [==============================] - 2s 150ms/step - loss: 0.5247 - accuracy: 0.8477 - val_loss: 1.3876 - val_accuracy: 0.4766
# Epoch 32/150
# 16/16 [==============================] - ETA: 0s - loss: 0.5673 - accuracy: 0.8086
# Epoch 32: val_loss did not improve from 1.23457
# 16/16 [==============================] - 2s 150ms/step - loss: 0.5673 - accuracy: 0.8086 - val_loss: 1.2853 - val_accuracy: 0.5234
# Epoch 33/150
# 16/16 [==============================] - ETA: 0s - loss: 0.5376 - accuracy: 0.8398
# Epoch 33: val_loss improved from 1.23457 to 1.21000, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 167ms/step - loss: 0.5376 - accuracy: 0.8398 - val_loss: 1.2100 - val_accuracy: 0.5938
# Epoch 34/150
# 16/16 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.8652
# Epoch 34: val_loss did not improve from 1.21000
# 16/16 [==============================] - 2s 150ms/step - loss: 0.4637 - accuracy: 0.8652 - val_loss: 1.2393 - val_accuracy: 0.5234
# Epoch 35/150
# 16/16 [==============================] - ETA: 0s - loss: 0.4587 - accuracy: 0.8613
# Epoch 35: val_loss improved from 1.21000 to 1.19346, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 167ms/step - loss: 0.4587 - accuracy: 0.8613 - val_loss: 1.1935 - val_accuracy: 0.5625
# Epoch 36/150
# 16/16 [==============================] - ETA: 0s - loss: 0.4164 - accuracy: 0.8789
# Epoch 36: val_loss did not improve from 1.19346
# 16/16 [==============================] - 2s 150ms/step - loss: 0.4164 - accuracy: 0.8789 - val_loss: 1.3161 - val_accuracy: 0.5391
# Epoch 37/150
# 16/16 [==============================] - ETA: 0s - loss: 0.4466 - accuracy: 0.8496
# Epoch 37: val_loss improved from 1.19346 to 1.18123, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 167ms/step - loss: 0.4466 - accuracy: 0.8496 - val_loss: 1.1812 - val_accuracy: 0.5859
# Epoch 38/150
# 16/16 [==============================] - ETA: 0s - loss: 0.4028 - accuracy: 0.8926
# Epoch 38: val_loss improved from 1.18123 to 1.16355, saving model to ./model_weights/VGG_r0_model_weights.h5
# 16/16 [==============================] - 3s 166ms/step - loss: 0.4028 - accuracy: 0.8926 - val_loss: 1.1635 - val_accuracy: 0.5781
# Epoch 39/150
# 16/16 [==============================] - ETA: 0s - loss: 0.3494 - accuracy: 0.8965
# Epoch 39: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 150ms/step - loss: 0.3494 - accuracy: 0.8965 - val_loss: 1.2309 - val_accuracy: 0.5781
# Epoch 40/150
# 16/16 [==============================] - ETA: 0s - loss: 0.3054 - accuracy: 0.9277
# Epoch 40: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.3054 - accuracy: 0.9277 - val_loss: 1.1744 - val_accuracy: 0.6016
# Epoch 41/150
# 16/16 [==============================] - ETA: 0s - loss: 0.3088 - accuracy: 0.9160
# Epoch 41: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.3088 - accuracy: 0.9160 - val_loss: 1.2802 - val_accuracy: 0.5703
# Epoch 42/150
# 16/16 [==============================] - ETA: 0s - loss: 0.3223 - accuracy: 0.9141
# Epoch 42: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 150ms/step - loss: 0.3223 - accuracy: 0.9141 - val_loss: 1.2484 - val_accuracy: 0.5234
# Epoch 43/150
# 16/16 [==============================] - ETA: 0s - loss: 0.3374 - accuracy: 0.8984
# Epoch 43: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 150ms/step - loss: 0.3374 - accuracy: 0.8984 - val_loss: 1.2332 - val_accuracy: 0.5547
# Epoch 44/150
# 16/16 [==============================] - ETA: 0s - loss: 0.2806 - accuracy: 0.9180
# Epoch 44: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.2806 - accuracy: 0.9180 - val_loss: 1.3025 - val_accuracy: 0.5625
# Epoch 45/150
# 16/16 [==============================] - ETA: 0s - loss: 0.3183 - accuracy: 0.9121
# Epoch 45: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.3183 - accuracy: 0.9121 - val_loss: 1.2617 - val_accuracy: 0.5859
# Epoch 46/150
# 16/16 [==============================] - ETA: 0s - loss: 0.3223 - accuracy: 0.9082
# Epoch 46: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.3223 - accuracy: 0.9082 - val_loss: 1.3523 - val_accuracy: 0.5938
# Epoch 47/150
# 16/16 [==============================] - ETA: 0s - loss: 0.2758 - accuracy: 0.9238
# Epoch 47: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.2758 - accuracy: 0.9238 - val_loss: 1.2386 - val_accuracy: 0.6094
# Epoch 48/150
# 16/16 [==============================] - ETA: 0s - loss: 0.2963 - accuracy: 0.8965
# Epoch 48: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.2963 - accuracy: 0.8965 - val_loss: 1.3697 - val_accuracy: 0.5625
# Epoch 49/150
# 16/16 [==============================] - ETA: 0s - loss: 0.2822 - accuracy: 0.9180
# Epoch 49: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 150ms/step - loss: 0.2822 - accuracy: 0.9180 - val_loss: 1.2904 - val_accuracy: 0.5625
# Epoch 50/150
# 16/16 [==============================] - ETA: 0s - loss: 0.2678 - accuracy: 0.9180
# Epoch 50: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 150ms/step - loss: 0.2678 - accuracy: 0.9180 - val_loss: 1.4248 - val_accuracy: 0.5469
# Epoch 51/150
# 16/16 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.9473
# Epoch 51: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.2296 - accuracy: 0.9473 - val_loss: 1.4177 - val_accuracy: 0.5781
# Epoch 52/150
# 16/16 [==============================] - ETA: 0s - loss: 0.2299 - accuracy: 0.9395
# Epoch 52: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.2299 - accuracy: 0.9395 - val_loss: 1.2405 - val_accuracy: 0.6094
# Epoch 53/150
# 16/16 [==============================] - ETA: 0s - loss: 0.2519 - accuracy: 0.9277
# Epoch 53: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.2519 - accuracy: 0.9277 - val_loss: 1.5442 - val_accuracy: 0.5234
# Epoch 54/150
# 16/16 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9375
# Epoch 54: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.2293 - accuracy: 0.9375 - val_loss: 1.2573 - val_accuracy: 0.5781
# Epoch 55/150
# 16/16 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9434
# Epoch 55: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.1967 - accuracy: 0.9434 - val_loss: 1.3808 - val_accuracy: 0.5859
# Epoch 56/150
# 16/16 [==============================] - ETA: 0s - loss: 0.1976 - accuracy: 0.9512
# Epoch 56: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 151ms/step - loss: 0.1976 - accuracy: 0.9512 - val_loss: 1.5495 - val_accuracy: 0.5312
# Epoch 57/150
# 16/16 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9414
# Epoch 57: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 150ms/step - loss: 0.2175 - accuracy: 0.9414 - val_loss: 1.3680 - val_accuracy: 0.5781
# Epoch 58/150
# 16/16 [==============================] - ETA: 0s - loss: 0.1612 - accuracy: 0.9688
# Epoch 58: val_loss did not improve from 1.16355
# 16/16 [==============================] - 2s 157ms/step - loss: 0.1612 - accuracy: 0.9688 - val_loss: 1.4125 - val_accuracy: 0.5547

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Get the training and validation loss from the history
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Get the training and validation accuracy from the history
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.savefig('./img/VGG_r0_loss_plot.png')

# Plot the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
plt.savefig('./img/VGG_r0_accuracy_plot.png')
# Out:
# /tmp/ipykernel_1755/2127484098.py:21: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /tmp/ipykernel_1755/2127484098.py:32: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
model.evaluate(x_test, y_test)
# Out:
# 4/4 [==============================] - 0s 110ms/step - loss: 0.9479 - accuracy: 0.6641
# [0.947852611541748, 0.6640625]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, f1_score

classes = ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# Assuming you have the predicted labels and true labels
y_pred = model.predict(x_test).argmax(axis=1)
y_true = np.argmax(y_test, axis=1)

# Calculate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Calculate the F1 score
f1 = f1_score(y_true, y_pred, average='weighted')

# Plot the confusion matrix
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
plt.savefig('./img/VGG_r0_confusion_matrix.png')
# Print the F1 score
print('F1 Score:', f1)
# Out:
# 4/4 [==============================] - 1s 174ms/step
# F1 Score: 0.6756203301608764
# /tmp/ipykernel_1755/2397229316.py:26: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
